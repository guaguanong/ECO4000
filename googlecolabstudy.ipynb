# %% [markdown]
# <a href="https://colab.research.google.com/github/guaguanong/ECO4000/blob/master/googlecolabstudy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# load libraries (which contains functions that are useful to our task)
# !pip install -U xlrd
import pandas as pd
import statsmodels.api as sm

# %%
# load data
df1 = pd.read_excel('Growth.xls')
df1.head()
# Out:
#     country_name    growth  oil       rgdp60  tradeshare  yearsschool  \
# 0          India  1.915168    0   765.999817    0.140502         1.45
# 1      Argentina  0.617645    0  4462.001465    0.156623         4.99
# 2          Japan  4.304759    0  2953.999512    0.157703         6.71
# 3         Brazil  2.930097    0  1783.999878    0.160405         2.89
# 4  United States  1.712265    0  9895.003906    0.160815         8.66
#
#    rev_coups  assasinations
# 0   0.133333       0.866667
# 1   0.933333       1.933333
# 2   0.000000       0.200000
# 3   0.100000       0.100000
# 4   0.000000       0.433333

# %%
# summary statistics
df1.describe()
# Out:
#           growth   oil       rgdp60  tradeshare  yearsschool  rev_coups  \
# count  65.000000  65.0    65.000000   65.000000    65.000000  65.000000
# mean    1.942715   0.0  3103.784649    0.564703     3.985077   0.167450
# std     1.897120   0.0  2512.656846    0.289270     2.542000   0.224680
# min    -2.811944   0.0   366.999939    0.140502     0.200000   0.000000
# 25%     0.838156   0.0  1147.999756    0.393251     1.940000   0.000000
# 50%     1.975147   0.0  2019.000244    0.543337     3.650000   0.066667
# 75%     2.880327   0.0  5143.000977    0.681555     5.560000   0.266667
# max     7.156855   0.0  9895.003906    1.992616    10.070000   0.970370
#
#        assasinations
# count      65.000000
# mean        0.277564
# std         0.491528
# min         0.000000
# 25%         0.000000
# 50%         0.100000
# 75%         0.233333
# max         2.466667

# %%
df1['const'] = 1
df1.head()
# Out:
#     country_name    growth  oil       rgdp60  tradeshare  yearsschool  \
# 0          India  1.915168    0   765.999817    0.140502         1.45
# 1      Argentina  0.617645    0  4462.001465    0.156623         4.99
# 2          Japan  4.304759    0  2953.999512    0.157703         6.71
# 3         Brazil  2.930097    0  1783.999878    0.160405         2.89
# 4  United States  1.712265    0  9895.003906    0.160815         8.66
#
#    rev_coups  assasinations  const
# 0   0.133333       0.866667      1
# 1   0.933333       1.933333      1
# 2   0.000000       0.200000      1
# 3   0.100000       0.100000      1
# 4   0.000000       0.433333      1

# %%
reg1 = sm.OLS(endog=df1['growth'], exog=df1[['tradeshare', 'const']])
results1 = reg1.fit()
print(results1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 growth   R-squared:                       0.124
# Model:                            OLS   Adj. R-squared:                  0.110
# Method:                 Least Squares   F-statistic:                     8.892
# Date:                Thu, 20 Mar 2025   Prob (F-statistic):            0.00407
# Time:                        03:02:55   Log-Likelihood:                -129.06
# No. Observations:                  65   AIC:                             262.1
# Df Residuals:                      63   BIC:                             266.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# tradeshare     2.3064      0.773      2.982      0.004       0.761       3.852
# ...

# %%
# Omitted Variable? Multiple Regression!
# Careful!!! There's a constant term in the exogenous variables!!!
reg2 = sm.OLS(endog=df1['growth'], exog=df1[['tradeshare','yearsschool','rgdp60','rev_coups','assasinations','const']])
results2 = reg2.fit()
print(results2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 growth   R-squared:                       0.359
# Model:                            OLS   Adj. R-squared:                  0.305
# Method:                 Least Squares   F-statistic:                     6.605
# Date:                Thu, 20 Mar 2025   Prob (F-statistic):           6.07e-05
# Time:                        03:10:47   Log-Likelihood:                -118.90
# No. Observations:                  65   AIC:                             249.8
# Df Residuals:                      59   BIC:                             262.8
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# tradeshare        1.5617      0.758      2.060      0.044       0.045       3.078
# ...

# %%
df2 = df1
df2 = df2.drop(index=[64])
df2
# Out:
#      country_name    growth  oil       rgdp60  tradeshare  yearsschool  \
# 0           India  1.915168    0   765.999817    0.140502         1.45
# 1       Argentina  0.617645    0  4462.001465    0.156623         4.99
# 2           Japan  4.304759    0  2953.999512    0.157703         6.71
# 3          Brazil  2.930097    0  1783.999878    0.160405         2.89
# 4   United States  1.712265    0  9895.003906    0.160815         8.66
# ..            ...       ...  ...          ...         ...          ...
# 59    Netherlands  2.200577    0  6076.997070    0.834204         5.27
# 60         Cyprus  5.384184    0  2037.000366    0.979355         4.29
# 61       Malaysia  4.114544    0  1420.000244    1.105364         2.34
# 62        Belgium  2.651335    0  5495.001953    1.115917         7.46
# 63      Mauritius  3.024178    0  2861.999268    1.127937         2.44
#
#     rev_coups  assasinations  const
# 0    0.133333       0.866667      1
# 1    0.933333       1.933333      1
# ...

# %%
reg3 = sm.OLS(endog=df2['growth'], exog=df2[['tradeshare','yearsschool','rgdp60','rev_coups','assasinations','const']])
results3 = reg3.fit()
print(results3.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 growth   R-squared:                       0.291
# Model:                            OLS   Adj. R-squared:                  0.230
# Method:                 Least Squares   F-statistic:                     4.764
# Date:                Thu, 20 Mar 2025   Prob (F-statistic):            0.00103
# Time:                        03:21:17   Log-Likelihood:                -117.49
# No. Observations:                  64   AIC:                             247.0
# Df Residuals:                      58   BIC:                             259.9
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# tradeshare        1.3408      0.960      1.397      0.168      -0.581       3.263
# ...
